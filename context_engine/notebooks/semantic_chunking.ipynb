# %%
from preprocessing.utils import clean_chunk
import io
from unstructured.partition.pdf import partition_pdf
from unstructured.documents.elements import (
    Table,
    NarrativeText,
    Title,
    ListItem,
    Image
)

# ---- Read PDF ----
with open("../data/coffee_processing.pdf", "rb") as f:
    pdf_bytes = f.read()

pdf_file = io.BytesIO(pdf_bytes)

elements = partition_pdf(
    file=pdf_file,
    infer_table_structure=True,
    extract_images_in_pdf=True,
)
# Out:
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Warning: No languages specified, defaulting to English.
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats
# Could not get FontBBox from font descriptor because None cannot be parsed as 4 floats

# %%
document_blocks = []

for i, el in enumerate(elements):

    page_number = el.metadata.page_number if el.metadata else None

    block = {
        "id": f"block_{i}",
        "type": None,
        "content": None,
        "section_title": None,
        "page": page_number,
        "summary": None
    }

    # ---- Detect Section Title (look backward) ----
    section_title = None
    for j in range(i - 1, max(i - 6, 0), -1):
        if isinstance(elements[j], Title):
            section_title = elements[j].text
            break

    block["section_title"] = section_title

    # ---- Store Based on Type ----
    if isinstance(el, (NarrativeText, Title, ListItem)) and el.text:
        block["type"] = "text"
        block["content"] = el.text

    elif isinstance(el, Table):
        block["type"] = "table"
        block["content"] = el.metadata.text_as_html

    elif isinstance(el, Image):
        block["type"] = "image"
        block["content"] = el.text if hasattr(el, "text") else ""

    # Append only valid blocks
    if block["type"]:
        document_blocks.append(block)

print("Total unified blocks:", len(document_blocks))

type_counts = {}
for block in document_blocks:
    type_counts[block["type"]] = type_counts.get(block["type"], 0) + 1

print(type_counts)
# Out:
# Total unified blocks: 29
# {'text': 25, 'table': 2, 'image': 2}

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOpenAI(
    model="gpt-3.5-turbo",
    temperature=0
)

# %%
analysis_prompt = ChatPromptTemplate.from_messages([
    ("system",
     "Generate dense semantic summaries for vector search.\n"
     "Use section title and previous document context to understand purpose.\n"
     "Ignore irrelevant context.\n"
     "Preserve important numbers.\n"
     "No conversational filler.\n"
     "Max 150 words."
    ),
    ("human",
     "Type: {type}\n"
     "Section: {section}\n"
     "Page: {page}\n\n"
     "Previous Context:\n{context}\n\n"
     "Current Content:\n{content}"
    )
])

# %%
CONTEXT_WINDOW = 3  # how many previous blocks to include

for i, block in enumerate(document_blocks):

    # We only summarize tables and images
    if block["type"] not in ["table", "image"]:
        continue

    # ---- Collect Previous Context ----
    prev_blocks = document_blocks[max(0, i - CONTEXT_WINDOW):i]

    context_text = ""
    for pb in prev_blocks:
        context_text += f"\n[{pb['type'].upper()}] {pb['content']}\n"

    messages = analysis_prompt.format_messages(
        type=block["type"],
        section=block["section_title"] or "Unknown",
        page=block["page"],
        context=context_text.strip(),
        content=block["content"] or "No extracted content."
    )

    response = llm.invoke(messages)

    block["summary"] = response.content.strip()

# %%
for i in document_blocks:
    print(i, end="\n\n")
# Out:
# {'id': 'block_0', 'type': 'text', 'content': 'Coffee Processing Methods', 'section_title': None, 'page': 1, 'summary': None}
#
# {'id': 'block_1', 'type': 'text', 'content': 'A Comprehensive Guide to Post-Harvest Coffee Processing', 'section_title': None, 'page': 1, 'summary': None}
#
# {'id': 'block_2', 'type': 'text', 'content': 'Coffee processing began in Ethiopia over 1,000 years ago.', 'section_title': None, 'page': 1, 'summary': None}
#
# {'id': 'block_3', 'type': 'text', 'content': 'Introduction to Coffee Processing', 'section_title': 'Coffee processing began in Ethiopia over 1,000 years ago.', 'page': 1, 'summary': None}
#
# {'id': 'block_4', 'type': 'text', 'content': 'Coffee processing is the method used to transform freshly picked coffee cherries into green coffee beans ready for roasting. The processing method significantly impacts the final flavor profile of the coffee. Different regions around the world have developed unique processing techniques based on their climate, available resources, and traditional practices. The choice of processing method can enhance certain flavor characteristics while suppressing others, making it one of the most critical decisions in coffee production.', 'section_title': 'Introduction to Coffee Processing', 'page': 1, 'summary': None}
#
# {'id': 'block_5', 'type': 'text', 'content': 'Processing begins immediately after harvest, as coffee cherries are highly perishable. The outer fruit must be removed, and the beans must be dried to prevent spoilage. The manner in which this is accomplished varies widely, from ancient sun-drying methods to modern mechanical processes. Each method requires different amounts of water, time, and labor, which influences both the cost of production and the environmental impact of coffee farming.', 'section_title': 'Introduction to Coffee Processing', 'page': 1, 'summary': None}
#
# {'id': 'block_6', 'type': 'text', 'content': 'The global coffee industry processes approximately 10 million tons of coffee cherries annually, with processing methods varying by region and producer size. Small-scale farmers often rely on traditional methods passed down through generations, while large estates may employ sophisticated machinery and controlled environments to ensure consistency and quality.', 'section_title': 'Introduction to Coffee Processing', 'page': 1, 'summary': None}
#
# {'id': 'block_8', 'type': 'text', 'content': 'Showing: Outer Skin → Pulp → Mucilage → Parchment → Silver Skin → Green Bean', 'section_title': 'Introduction to Coffee Processing', 'page': 1, 'summary': None}
#
# {'id': 'block_9', 'type': 'text', 'content': 'Explore our developer-friendly HTML to PDF API', 'section_title': None, 'page': 1, 'summary': None}
#
# {'id': 'block_12', 'type': 'text', 'content': 'Primary Processing Methods', 'section_title': None, 'page': 2, 'summary': None}
#
# {'id': 'block_13', 'type': 'table', 'content': '<table><thead><tr><th>Method</th><th>Water Usage</th><th>Flavor Profile</th><th>Common Regions</th></tr></thead><tbody><tr><td>Washed (Wet)</td><td>High (150L per gh (1501 p kg)</td><td>Clean, bright, 6 acidic</td><td>Colombia, Central America</td></tr><tr><td>Natural (Dry)</td><td>Minimal</td><td>Fruity, sweet, full- ; bodied</td><td>Ethiopia, Brazil</td></tr><tr><td>Honey/Pulped Natural</td><td>Medium (50L per kg)</td><td>Balanced, sweet</td><td>; ; Costa Rica, Brazil</td></tr><tr><td>Semi-washed</td><td>Medium-High</td><td>Moderate acidity, y clean</td><td>Indonesia, India</td></tr></tbody></table>', 'section_title': 'Primary Processing Methods', 'page': 2, 'summary': 'The table in the "Primary Processing Methods" section on page 2 outlines different coffee processing methods. Washed (Wet) method uses high water usage of 150L per kg, common in Colombia and Central America. Natural (Dry) method has minimal water usage, popular in Ethiopia and Brazil. Honey/Pulped Natural method uses medium water usage of 50L per kg, common in Costa Rica and Brazil. Semi-washed method falls in the medium-high water usage range, found in Indonesia and India. Each method results in distinct flavor profiles and is associated with specific coffee-growing regions.'}
#
# {'id': 'block_14', 'type': 'image', 'content': '$ Growing 4 ti a arvesting wv LA Planting y_N ‘ik ah ~) Grinding Coffee processing : Ye po Bex Brewing shutterstsck:', 'section_title': 'Primary Processing Methods', 'page': 2, 'summary': 'Primary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed coffee uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile common in Colombia and Central America. Natural processing requires minimal water and produces a fruity and sweet taste found in Ethiopia and Brazil. Honey/pulped natural method involves medium water usage and creates a balanced and sweet flavor typical in Costa Rica and Brazil. Semi-washed coffee falls between medium to high water usage, offering moderate acidity and cleanliness, commonly seen in Indonesia and India. Each method contributes to the unique flavor profiles of coffee beans from different regions.'}
#
# {'id': 'block_15', 'type': 'image', 'content': '', 'section_title': 'Primary Processing Methods', 'page': 2, 'summary': 'Primary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed method uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile, common in Colombia and Central America. Natural method requires minimal water and produces a fruity and sweet flavor, popular in Ethiopia and Brazil. Honey/pulped natural method uses medium water usage of 50 liters per kilogram, creating a balanced and sweet taste found in Costa Rica and Brazil. Semi-washed method falls in between with moderate to high water usage, offering moderate acidity and a clean flavor, commonly seen in Indonesia and India. Each method contributes to the unique characteristics of coffee beans from different regions.'}
#
# {'id': 'block_17', 'type': 'text', 'content': 'Explore our developer-friendly HTML to PDF API', 'section_title': 'Primary Processing Methods', 'page': 2, 'summary': None}
#
# {'id': 'block_20', 'type': 'text', 'content': 'Washed Processing Method', 'section_title': None, 'page': 3, 'summary': None}
#
# {'id': 'block_21', 'type': 'text', 'content': 'The washed process, also known as wet processing, is the most widely used method for high-quality arabica coffee. This method involves removing all of the fruit from the coffee bean before drying. First, the outer skin and pulp are mechanically removed using a depulping machine. The beans, still covered in a sticky layer called mucilage, are then fermented in water tanks for 12 to 48 hours. During fermentation, naturally occurring enzymes and bacteria break down the mucilage. After fermentation, the beans are thoroughly washed with clean water to remove any remaining mucilage residue.', 'section_title': 'Washed Processing Method', 'page': 3, 'summary': None}
#
# {'id': 'block_22', 'type': 'text', 'content': "Following the washing stage, the beans are dried either on raised beds or patios until they reach the optimal moisture content of 11-12 percent. This careful drying process can take anywhere from 7 to 14 days depending on weather conditions and drying infrastructure. The washed method produces coffee with exceptional clarity of flavor, allowing the bean's inherent characteristics to shine through. However, this method requires significant amounts of clean water and generates wastewater that must be properly managed to avoid environmental contamination.", 'section_title': 'Washed Processing Method', 'page': 3, 'summary': None}
#
# {'id': 'block_23', 'type': 'text', 'content': 'Environmental Note: Modern wet mills are increasingly implementing water recycling systems and eco-pulping technologies to reduce water consumption by up to 90 percent while maintaining quality standards.', 'section_title': 'Washed Processing Method', 'page': 3, 'summary': None}
#
# {'id': 'block_24', 'type': 'text', 'content': 'Natural Processing Method', 'section_title': 'Washed Processing Method', 'page': 3, 'summary': None}
#
# {'id': 'block_25', 'type': 'text', 'content': 'Natural processing, the oldest coffee processing method, requires minimal equipment and no water beyond what occurs naturally through rain. Whole coffee cherries are spread in thin layers on raised drying beds, patios, or even on the ground in some traditional operations. The cherries must be regularly turned to ensure even drying and prevent mold growth. This process takes 3 to 4 weeks depending on climate conditions, with optimal drying occurring in regions with consistent sunshine and low humidity.', 'section_title': 'Natural Processing Method', 'page': 3, 'summary': None}
#
# {'id': 'block_26', 'type': 'text', 'content': 'During the extended drying period, the coffee bean continues to absorb sugars and flavors from the surrounding fruit, resulting in a distinctly fruity and complex cup profile. The natural method produces coffees with pronounced sweetness, heavier body, and exotic fruit notes. However, this method carries higher risk of defects if not carefully monitored, as over-fermentation or uneven drying can lead to off-flavors.', 'section_title': 'Natural Processing Method', 'page': 3, 'summary': None}
#
# {'id': 'block_27', 'type': 'text', 'content': 'Explore our developer-friendly HTML to PDF API', 'section_title': 'Natural Processing Method', 'page': 3, 'summary': None}
#
# {'id': 'block_30', 'type': 'text', 'content': '🌞 Coffee Drying Beds 🌞', 'section_title': None, 'page': 4, 'summary': None}
#
# {'id': 'block_31', 'type': 'text', 'content': 'Natural Process: Whole cherries drying in the sun on raised beds', 'section_title': '🌞 Coffee Drying Beds 🌞', 'page': 4, 'summary': None}
#
# {'id': 'block_32', 'type': 'text', 'content': 'Quality Control and Final Steps', 'section_title': '🌞 Coffee Drying Beds 🌞', 'page': 4, 'summary': None}
#
# {'id': 'block_33', 'type': 'table', 'content': '<table><thead><tr><th>Processing Stage</th><th>Quality Check</th><th>Target Specification</th></tr></thead><tbody><tr><td>Moisture Content</td><td>Electronic moisture meter</td><td>10.5-12.5%</td></tr><tr><td>Bean Sorting</td><td>Visual and mechanical sorting</td><td>Less than 5% defects</td></tr><tr><td>Density Grading</td><td>Gravity separation</td><td>Screen size 15+ for specialty</td></tr><tr><td>Color Sorting</td><td>Optical color sorters</td><td>Uniform green color</td></tr></tbody></table>', 'section_title': 'Quality Control and Final Steps', 'page': 4, 'summary': 'In the Quality Control and Final Steps section, a table outlines the processing stages, quality checks, and target specifications for coffee production. The stages include checking moisture content with an electronic meter aiming for 10.5-12.5%, sorting beans visually and mechanically to achieve less than 5% defects, grading density through gravity separation with a screen size of 15+ for specialty beans, and sorting by color using optical color sorters to ensure a uniform green color. These meticulous quality control measures are crucial in maintaining the high standards and consistency of the final coffee product.'}
#
# {'id': 'block_34', 'type': 'text', 'content': 'After processing and drying, green coffee beans undergo milling to remove the parchment layer (in washed coffee) or the entire dried fruit (in natural coffee). The beans are then graded based on size, density, and defect count. Specialty grade coffee must meet stringent criteria with no more than 5 primary defects per 300 grams of green beans. Finally, the processed beans are packaged in moisture-controlled environments, typically in 60-70 kilogram jute or GrainPro bags, ready for export to roasters worldwide.', 'section_title': 'Quality Control and Final Steps', 'page': 4, 'summary': None}
#
# {'id': 'block_35', 'type': 'text', 'content': 'Print to PDF', 'section_title': 'Quality Control and Final Steps', 'page': 4, 'summary': None}
#
# {'id': 'block_36', 'type': 'text', 'content': 'Explore our developer-friendly HTML to PDF API', 'section_title': 'Quality Control and Final Steps', 'page': 4, 'summary': None}

# %%
cleaned_parts = []

for block in document_blocks:

    if block["type"] == "text":
        if block["content"]:
            cleaned_parts.append(block["content"].strip())

    elif block["type"] in ["table", "image"]:
        if block["summary"]:
            cleaned_parts.append(block["summary"].strip())

# Join everything sequentially
cleaned_document = "\n\n".join(cleaned_parts)

cleaned_document
# Out:
# 'Coffee Processing Methods\n\nA Comprehensive Guide to Post-Harvest Coffee Processing\n\nCoffee processing began in Ethiopia over 1,000 years ago.\n\nIntroduction to Coffee Processing\n\nCoffee processing is the method used to transform freshly picked coffee cherries into green coffee beans ready for roasting. The processing method significantly impacts the final flavor profile of the coffee. Different regions around the world have developed unique processing techniques based on their climate, available resources, and traditional practices. The choice of processing method can enhance certain flavor characteristics while suppressing others, making it one of the most critical decisions in coffee production.\n\nProcessing begins immediately after harvest, as coffee cherries are highly perishable. The outer fruit must be removed, and the beans must be dried to prevent spoilage. The manner in which this is accomplished varies widely, from ancient sun-drying methods to modern mechanical processes. Each method requires different amounts of water, time, and labor, which influences both the cost of production and the environmental impact of coffee farming.\n\nThe global coffee industry processes approximately 10 million tons of coffee cherries annually, with processing methods varying by region and producer size. Small-scale farmers often rely on traditional methods passed down through generations, while large estates may employ sophisticated machinery and controlled environments to ensure consistency and quality.\n\nShowing: Outer Skin → Pulp → Mucilage → Parchment → Silver Skin → Green Bean\n\nExplore our developer-friendly HTML to PDF API\n\nPrimary Processing Methods\n\nThe table in the "Primary Processing Methods" section on page 2 outlines different coffee processing methods. Washed (Wet) method uses high water usage of 150L per kg, common in Colombia and Central America. Natural (Dry) method has minimal water usage, popular in Ethiopia and Brazil. Honey/Pulped Natural method uses medium water usage of 50L per kg, common in Costa Rica and Brazil. Semi-washed method falls in the medium-high water usage range, found in Indonesia and India. Each method results in distinct flavor profiles and is associated with specific coffee-growing regions.\n\nPrimary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed coffee uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile common in Colombia and Central America. Natural processing requires minimal water and produces a fruity and sweet taste found in Ethiopia and Brazil. Honey/pulped natural method involves medium water usage and creates a balanced and sweet flavor typical in Costa Rica and Brazil. Semi-washed coffee falls between medium to high water usage, offering moderate acidity and cleanliness, commonly seen in Indonesia and India. Each method contributes to the unique flavor profiles of coffee beans from different regions.\n\nPrimary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed method uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile, common in Colombia and Central America. Natural method requires minimal water and produces a fruity and sweet flavor, popular in Ethiopia and Brazil. Honey/pulped natural method uses medium water usage of 50 liters per kilogram, creating a balanced and sweet taste found in Costa Rica and Brazil. Semi-washed method falls in between with moderate to high water usage, offering moderate acidity and a clean flavor, commonly seen in Indonesia and India. Each method contributes to the unique characteristics of coffee beans from different regions.\n\nExplore our developer-friendly HTML to PDF API\n\nWashed Processing Method\n\nThe washed process, also known as wet processing, is the most widely used method for high-quality arabi ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.documents import Document


text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=80,
    separators=["\n\n", "\n", ". ", " "]
)
chunks = text_splitter.create_documents([cleaned_document])


cleaned_documents = []

for i, chunk in enumerate(chunks):
    raw_text = chunk.page_content
    cleaned_text = clean_chunk(raw_text)
    
    doc = Document(
        page_content=cleaned_text,
        metadata={
            "source": "coffee_processing_guide",
            "chunk_id": i
        }
    )
    cleaned_documents.append(doc)

print(f'Total no of chunks: {len(chunks)}', end='\n\n')
for doc in cleaned_documents:
    print(doc.page_content)
    print("-" * 40)
# Out:
# Total no of chunks: 27
#
# Coffee Processing Methods A Comprehensive Guide to Post-Harvest Coffee Processing Coffee processing began in Ethiopia over 1,000 years ago. Introduction to Coffee Processing
# ----------------------------------------
# Coffee processing is the method used to transform freshly picked coffee cherries into green coffee beans ready for roasting. The processing method significantly impacts the final flavor profile of the coffee. Different regions around the world have developed unique processing techniques based on their climate, available resources, and traditional practices
# ----------------------------------------
# The choice of processing method can enhance certain flavor characteristics while suppressing others, making it one of the most critical decisions in coffee production.
# ----------------------------------------
# Processing begins immediately after harvest, as coffee cherries are highly perishable. The outer fruit must be removed, and the beans must be dried to prevent spoilage. The manner in which this is accomplished varies widely, from ancient sun-drying methods to modern mechanical processes. Each method requires different amounts of water, time, and labor, which influences both the cost of production and the environmental impact of coffee farming.
# ----------------------------------------
# The global coffee industry processes approximately 10 million tons of coffee cherries annually, with processing methods varying by region and producer size. Small-scale farmers often rely on traditional methods passed down through generations, while large estates may employ sophisticated machinery and controlled environments to ensure consistency and quality. Showing: Outer Skin → Pulp → Mucilage → Parchment → Silver Skin → Green Bean Explore our developer-friendly HTML to PDF API
# ----------------------------------------
# Explore our developer-friendly HTML to PDF API Primary Processing Methods
# ----------------------------------------
# The table in the "Primary Processing Methods" section on page 2 outlines different coffee processing methods. Washed (Wet) method uses high water usage of 150L per kg, common in Colombia and Central America. Natural (Dry) method has minimal water usage, popular in Ethiopia and Brazil. Honey/Pulped Natural method uses medium water usage of 50L per kg, common in Costa Rica and Brazil. Semi-washed method falls in the medium-high water usage range, found in Indonesia and India
# ----------------------------------------
# Each method results in distinct flavor profiles and is associated with specific coffee-growing regions.
# ----------------------------------------
# Primary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed coffee uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile common in Colombia and Central America. Natural processing requires minimal water and produces a fruity and sweet taste found in Ethiopia and Brazil
# ----------------------------------------
# Honey/pulped natural method involves medium water usage and creates a balanced and sweet flavor typical in Costa Rica and Brazil. Semi-washed coffee falls between medium to high water usage, offering moderate acidity and cleanliness, commonly seen in Indonesia and India. Each method contributes to the unique flavor profiles of coffee beans from different regions.
# ----------------------------------------
# Primary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed method uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile, common in Colombia and Central America. Natural method requires minimal water and produces a fruity and sweet flavor, popular in Ethiopia and Brazil
# ----------------------------------------
# Honey/pulped natural method uses medium water usage of 50 liters per kilogram, creating a balanced and sweet taste found in Costa Rica and Brazil. Semi-washed method falls in between with moderate to high water usage, offering moderate acidity and a clean flavor, commonly seen in Indonesia and India. Each method contributes to the unique characteristics of coffee beans from different regions.
# ----------------------------------------
# Explore our developer-friendly HTML to PDF API Washed Processing Method
# ----------------------------------------
# The washed process, also known as wet processing, is the most widely used method for high-quality arabica coffee. This method involves removing all of the fruit from the coffee bean before drying. First, the outer skin and pulp are mechanically removed using a depulping machine. The beans, still covered in a sticky layer called mucilage, are then fermented in water tanks for 12 to 48 hours. During fermentation, naturally occurring enzymes and bacteria break down the mucilage
# ----------------------------------------
# After fermentation, the beans are thoroughly washed with clean water to remove any remaining mucilage residue.
# ----------------------------------------
# Following the washing stage, the beans are dried either on raised beds or patios until they reach the optimal moisture content of 11-12 percent. This careful drying process can take anywhere from 7 to 14 days depending on weather conditions and drying infrastructure. The washed method produces coffee with exceptional clarity of flavor, allowing the bean's inherent characteristics to shine through
# ----------------------------------------
# However, this method requires significant amounts of clean water and generates wastewater that must be properly managed to avoid environmental contamination.
# ----------------------------------------
# Environmental Note: Modern wet mills are increasingly implementing water recycling systems and eco-pulping technologies to reduce water consumption by up to 90 percent while maintaining quality standards. Natural Processing Method
# ----------------------------------------
# Natural processing, the oldest coffee processing method, requires minimal equipment and no water beyond what occurs naturally through rain. Whole coffee cherries are spread in thin layers on raised drying beds, patios, or even on the ground in some traditional operations. The cherries must be regularly turned to ensure even drying and prevent mold growth
# ----------------------------------------
# This process takes 3 to 4 weeks depending on climate conditions, with optimal drying occurring in regions with consistent sunshine and low humidity.
# ----------------------------------------
# During the extended drying period, the coffee bean continues to absorb sugars and flavors from the surrounding fruit, resulting in a distinctly fruity and complex cup profile. The natural method produces coffees with pronounced sweetness, heavier body, and exotic fruit notes. However, this method carries higher risk of defects if not carefully monitored, as over-fermentation or uneven drying can lead to off-flavors. Explore our developer-friendly HTML to PDF API 🌞 Coffee Drying Beds 🌞
# ----------------------------------------
# Explore our developer-friendly HTML to PDF API 🌞 Coffee Drying Beds 🌞 Natural Process: Whole cherries drying in the sun on raised beds Quality Control and Final Steps
# ----------------------------------------
# In the Quality Control and Final Steps section, a table outlines the processing stages, quality checks, and target specifications for coffee production. The stages include checking moisture content with an electronic meter aiming for 10.5-12.5%, sorting beans visually and mechanically to achieve less than 5% defects, grading density through gravity separation with a screen size of 15+ for specialty beans, and sorting by color using optical color sorters to ensure a uniform green color
# ----------------------------------------
# These meticulous quality control measures are crucial in maintaining the high standards and consistency of the final coffee product.
# ----------------------------------------
# After processing or the entire dried fruit (in natural coffee). The beans are then graded based on size, density, and defect count. Specialty grade coffee must meet stringent criteria with no more than 5 primary defects per 300 grams of green beans
# ----------------------------------------
# Finally, the processed beans are packaged in moisture-controlled environments, typically in 60-70 kilogram jute or GrainPro bags, ready for export to roasters worldwide.
# ----------------------------------------
# Explore our developer-friendly HTML to PDF API
# ----------------------------------------

# %%
from langchain_openai import OpenAIEmbeddings
import chromadb

# Initialize embeddings model
embeddings_model = OpenAIEmbeddings(model="text-embedding-3-large")

# Set up ChromaDB client with persistent storage
chroma_client = chromadb.PersistentClient(path="../chroma_db")

# %%
collection = chroma_client.get_collection(name="my_documents_semantic_chunking")
print(collection.count())
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 collection = chroma_client.get_collection(name="my_documents_semantic_chunking")
#       2 print(collection.count())
#
# File ~/Desktop/personal_projects/RAG/.venv/lib/python3.12/site-packages/chromadb/api/client.py:208, in Client.get_collection(self, name, embedding_function, data_loader)
#     199 @override
#     200 def get_collection(
#     201     self,
#    (...)    206     data_loader: Optional[DataLoader[Loadable]] = None,
#     207 ) -> Collection:
# --> 208     model = self._server.get_collection(
#     209         name=name,
#     210         tenant=self.tenant,
#     211         database=self.database,
#     212     )
#     213     persisted_ef_config = model.configuration_json.get("embedding_function")
#     215     validate_embedding_function_conflict_on_get(
#     216         embedding_function, persisted_ef_config
#     217     )
#
# File ~/Desktop/personal_projects/RAG/.venv/lib/python3.12/site-packages/chromadb/api/rust.py:271, in RustBindingsAPI.get_collection(self, name, tenant, database)
#     264 @override
#     265 def get_collection(
#     266     self,
#    (...)    269     database: str = DEFAULT_DATABASE,
#     270 ) -> CollectionModel:
# --> 271     collection = self.bindings.get_collection(name, tenant, database)
#     272     return CollectionModel(
#     273         id=collection.id,
#     274         name=collection.name,
#    (...)    280         database=collection.database,
#     281     )
#
# NotFoundError: Collection [my_documents_semantic_chunking] does not exist

# %%
# Delete existing collection if it exists (truncate)
try:
    chroma_client.delete_collection(name="my_documents_semantic_chunking")
    print("Existing collection deleted")
except:
    print("No existing collection found")

# Create new collection
collection = chroma_client.create_collection(
    name="my_documents_semantic_chunking",
    metadata={"description": "Document embeddings collection"}
)
# Out:
# No existing collection found

# %%
from langchain_experimental.text_splitter import SemanticChunker


splitter = SemanticChunker(
    embeddings=embeddings_model,
    breakpoint_threshold_type="percentile",
    breakpoint_threshold_amount=90,
    min_chunk_size=300
)

chunks = splitter.split_text(cleaned_document)

# %%
for chunk in chunks:
    if chunk:
        print("-"*10, len(chunk), "-"*10)
        print(chunk)
# Out:
# ---------- 1876 ----------
# Coffee Processing Methods
#
# A Comprehensive Guide to Post-Harvest Coffee Processing
#
# Coffee processing began in Ethiopia over 1,000 years ago. Introduction to Coffee Processing
#
# Coffee processing is the method used to transform freshly picked coffee cherries into green coffee beans ready for roasting. The processing method significantly impacts the final flavor profile of the coffee. Different regions around the world have developed unique processing techniques based on their climate, available resources, and traditional practices. The choice of processing method can enhance certain flavor characteristics while suppressing others, making it one of the most critical decisions in coffee production. Processing begins immediately after harvest, as coffee cherries are highly perishable. The outer fruit must be removed, and the beans must be dried to prevent spoilage. The manner in which this is accomplished varies widely, from ancient sun-drying methods to modern mechanical processes. Each method requires different amounts of water, time, and labor, which influences both the cost of production and the environmental impact of coffee farming. The global coffee industry processes approximately 10 million tons of coffee cherries annually, with processing methods varying by region and producer size. Small-scale farmers often rely on traditional methods passed down through generations, while large estates may employ sophisticated machinery and controlled environments to ensure consistency and quality. Showing: Outer Skin → Pulp → Mucilage → Parchment → Silver Skin → Green Bean
#
# Explore our developer-friendly HTML to PDF API
#
# Primary Processing Methods
#
# The table in the "Primary Processing Methods" section on page 2 outlines different coffee processing methods. Washed (Wet) method uses high water usage of 150L per kg, common in Colombia and Central America.
# ---------- 1813 ----------
# Natural (Dry) method has minimal water usage, popular in Ethiopia and Brazil. Honey/Pulped Natural method uses medium water usage of 50L per kg, common in Costa Rica and Brazil. Semi-washed method falls in the medium-high water usage range, found in Indonesia and India. Each method results in distinct flavor profiles and is associated with specific coffee-growing regions. Primary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed coffee uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile common in Colombia and Central America. Natural processing requires minimal water and produces a fruity and sweet taste found in Ethiopia and Brazil. Honey/pulped natural method involves medium water usage and creates a balanced and sweet flavor typical in Costa Rica and Brazil. Semi-washed coffee falls between medium to high water usage, offering moderate acidity and cleanliness, commonly seen in Indonesia and India. Each method contributes to the unique flavor profiles of coffee beans from different regions. Primary processing methods in coffee production include washed (wet), natural (dry), honey/pulped natural, and semi-washed. Washed method uses high water usage of 150 liters per kilogram, resulting in a clean and bright flavor profile, common in Colombia and Central America. Natural method requires minimal water and produces a fruity and sweet flavor, popular in Ethiopia and Brazil. Honey/pulped natural method uses medium water usage of 50 liters per kilogram, creating a balanced and sweet taste found in Costa Rica and Brazil. Semi-washed method falls in between with moderate to high water usage, offering moderate acidity and a clean flavor, commonly seen in Indonesia and India.
# ---------- 364 ----------
# Each method contributes to the unique characteristics of coffee beans from different regions. Explore our developer-friendly HTML to PDF API
#
# Washed Processing Method
#
# The washed process, also known as wet processing, is the most widely used method for high-quality arabica coffee. This method involves removing all of the fruit from the coffee bean before drying.
# ---------- 1458 ----------
# First, the outer skin and pulp are mechanically removed using a depulping machine. The beans, still covered in a sticky layer called mucilage, are then fermented in water tanks for 12 to 48 hours. During fermentation, naturally occurring enzymes and bacteria break down the mucilage. After fermentation, the beans are thoroughly washed with clean water to remove any remaining mucilage residue. Following the washing stage, the beans are dried either on raised beds or patios until they reach the optimal moisture content of 11-12 percent. This careful drying process can take anywhere from 7 to 14 days depending on weather conditions and drying infrastructure. The washed method produces coffee with exceptional clarity of flavor, allowing the bean's inherent characteristics to shine through. However, this method requires significant amounts of clean water and generates wastewater that must be properly managed to avoid environmental contamination. Environmental Note: Modern wet mills are increasingly implementing water recycling systems and eco-pulping technologies to reduce water consumption by up to 90 percent while maintaining quality standards. Natural Processing Method
#
# Natural processing, the oldest coffee processing method, requires minimal equipment and no water beyond what occurs naturally through rain. Whole coffee cherries are spread in thin layers on raised drying beds, patios, or even on the ground in some traditional operations.
# ---------- 510 ----------
# The cherries must be regularly turned to ensure even drying and prevent mold growth. This process takes 3 to 4 weeks depending on climate conditions, with optimal drying occurring in regions with consistent sunshine and low humidity. During the extended drying period, the coffee bean continues to absorb sugars and flavors from the surrounding fruit, resulting in a distinctly fruity and complex cup profile. The natural method produces coffees with pronounced sweetness, heavier body, and exotic fruit notes.
# ---------- 804 ----------
# However, this method carries higher risk of defects if not carefully monitored, as over-fermentation or uneven drying can lead to off-flavors. Explore our developer-friendly HTML to PDF API
#
# 🌞 Coffee Drying Beds 🌞
#
# Natural Process: Whole cherries drying in the sun on raised beds
#
# Quality Control and Final Steps
#
# In the Quality Control and Final Steps section, a table outlines the processing stages, quality checks, and target specifications for coffee production. The stages include checking moisture content with an electronic meter aiming for 10.5-12.5%, sorting beans visually and mechanically to achieve less than 5% defects, grading density through gravity separation with a screen size of 15+ for specialty beans, and sorting by color using optical color sorters to ensure a uniform green color.
# ---------- 709 ----------
# These meticulous quality control measures are crucial in maintaining the high standards and consistency of the final coffee product. After processing and drying, green coffee beans undergo milling to remove the parchment layer (in washed coffee) or the entire dried fruit (in natural coffee). The beans are then graded based on size, density, and defect count. Specialty grade coffee must meet stringent criteria with no more than 5 primary defects per 300 grams of green beans. Finally, the processed beans are packaged in moisture-controlled environments, typically in 60-70 kilogram jute or GrainPro bags, ready for export to roasters worldwide. Print to PDF
#
# Explore our developer-friendly HTML to PDF API

# %%
# Calculate embeddings in batches and prepare data
documents = []
embeddings_list = []
ids = []

# Extract all texts first
all_texts = []
for idx, chunk in enumerate(chunks):
    text = chunk["page_content"] if isinstance(chunk, dict) else chunk.page_content
    all_texts.append(text)
    ids.append(f"doc_{idx}")

# Calculate embeddings in batches
batch_size = 100  # Adjust based on your needs and API limits
total_batches = (len(all_texts) + batch_size - 1) // batch_size

print(f"Processing {len(all_texts)} documents in {total_batches} batches...")

for i in range(0, len(all_texts), batch_size):
    batch_texts = all_texts[i:i + batch_size]
    
    # Calculate embeddings for the batch
    batch_embeddings = embeddings_model.embed_documents(batch_texts)
    
    # Add to main lists
    documents.extend(batch_texts)
    embeddings_list.extend(batch_embeddings)
    
    batch_num = (i // batch_size) + 1
    print(f"Processed batch {batch_num}/{total_batches} ({len(batch_texts)} documents)")

print(f"\nTotal embeddings calculated: {len(embeddings_list)}")

# Insert all data into ChromaDB
collection.add(
    documents=documents,
    embeddings=embeddings_list,
    ids=ids
)

print(f"Successfully added {len(documents)} documents to ChromaDB")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 9
#       7 all_texts = []
#       8 for idx, chunk in enumerate(chunks):
# ----> 9     text = chunk["page_content"] if isinstance(chunk, dict) else chunk.page_content
#      10     all_texts.append(text)
#      11     ids.append(f"doc_{idx}")
#
# AttributeError: 'str' object has no attribute 'page_content'

# %%
# Perform similarity search
query = """Natural (dry) processing requires minimal water and produces a fruity and sweet flavor, often found in Ethiopia and Brazil. Honey/pulped natural processing involves medium water usage, creating a balanced and sweet taste, commonly found in Costa Rica and Brazil. Semi-washed processing falls in the medium-high water usage range, resulting in moderate acidity and cleanliness, typically found in Indonesia and India. The table outlines quality control measures during the final steps of coffee processing. It includes checks for moisture content (target 10.5-12.5%), bean sorting (less than 5% defects), density grading (screen size 15+ for specialty), and color sorting (uniform green color)"""

# Calculate query embedding
query_embedding = embeddings_model.embed_query(query)

# Search for top K similar documents
k = 10  # Number of results to return

results = collection.query(
    query_embeddings=[query_embedding],
    n_results=k
)

# Print results
print(f"Query: '{query}'\n")
print(f"Top {k} similar documents:\n")
print("=" * 80)
print(results)

for i in range(len(results['ids'][0])):
    distance = results['distances'][0][i]
    
    # Correct conversion: cosine similarity = 1 - cosine distance
    # Then convert to percentage
    cosine_similarity = 1 - distance
    confidence_percentage = cosine_similarity * 100
    
    print(f"\nRank {i + 1}:")
    print(f"ID: {results['ids'][0][i]}")
    print(f"Raw Text: {results['documents'][0][i]}")
    print(f"Cosine Distance: {distance:.4f}")
    print(f"Cosine Similarity: {cosine_similarity:.4f}")
    print(f"Confidence: {confidence_percentage:.2f}%")
    print("-" * 80)
# Out:
# Query: 'Natural (dry) processing requires minimal water and produces a fruity and sweet flavor, often found in Ethiopia and Brazil. Honey/pulped natural processing involves medium water usage, creating a balanced and sweet taste, commonly found in Costa Rica and Brazil. Semi-washed processing falls in the medium-high water usage range, resulting in moderate acidity and cleanliness, typically found in Indonesia and India. The table outlines quality control measures during the final steps of coffee processing. It includes checks for moisture content (target 10.5-12.5%), bean sorting (less than 5% defects), density grading (screen size 15+ for specialty), and color sorting (uniform green color)'
#
# Top 10 similar documents:
#
# ================================================================================
# {'ids': [[]], 'embeddings': None, 'documents': [[]], 'uris': None, 'included': ['metadatas', 'documents', 'distances'], 'data': None, 'metadatas': [[]], 'distances': [[]]}
