# %%
pdf_path = "/Users/nnandagopal/Desktop/personal_projects/RAG/data/coffee_processing.pdf"

# %%
from pathlib import Path
from docling.document_converter import DocumentConverter

# Create converter (no config)
converter = DocumentConverter()

# %%
input_pdf = Path("/Users/nnandagopal/Desktop/personal_projects/RAG/data/example1.pdf")
output_dir = Path("output")
output_dir.mkdir(exist_ok=True)

markdown_path = output_dir / "document.md"

# Convert PDF
result = converter.convert(str(input_pdf))

# %%
# Export markdown + images
markdown = result.document.export_to_markdown(
)

markdown_path.write_text(markdown, encoding="utf-8")

print("Saved:", markdown_path)
# Out:
# Saved: output/document.md
